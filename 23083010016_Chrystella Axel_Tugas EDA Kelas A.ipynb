# %% [markdown]
# Nama  : Chrystella Axel Alexandra

# %% [markdown]
# NPM   : 23083010016

# %% [markdown]
# Kelas : Analisis Data Eksploratif (A)

# %% [markdown]
# # Deskripsi

# %% [markdown]
# Data ini merupakan data tentang laporan kekerasan dan kejahatan terhadap perempuan, dibeberapa wilayah, Negara India yang diambil pada tahun 2001 - 2021. Data tersebut telah direkap dari situs data.govin, yakni portal resmi yang disediakan pemerintahan Negara India. Data ini diperlukan untuk menganalisis dan memantau perkembangan (bertambah atau berkurang) tingkat kasus kekerasan dan kejahatan terhadap perempuan, berdasarkan variabel - variabel yang diamati, yakni sebagai berikut.

# %% [markdown]
# 1. No : Nomer urut
# 2. State : Wilayah di Negara India
# 3. Year : Tahun kejadian kekerasan dan kejahatan terhadap perempuan dalam rentang tahun 2001 - 2021.
# 4. Rape : Kasus pemerkosaan tehadap perempuan.
# 5. K&A (Kidnapping & Abduction) : Kasus penculikan terhadap perempuan yang melibatkan unsur ancaman atau non
#    ancaman (tipu daya).
# 6. DD (Dowry Deaths) : Kasus kematian dikarenakan kekerasan atau pelecahan didalam rumah tangga.
# 7. AoW (Assault Against Women) : Kasus kekerasan atau serangan secara fisik, seksual, ddan psikologis terhadap
#    perempuan.
# 8. AoM (Assault Against Women Modesty Of Women) : Kasus yang mengacu pada tindakan merusak, melanggar, dan
#    menyerang kehormatan serta martabat perempuan.
# 9. DV (Domestic Violence) : Kasus Kekerasan Dalam Rumah Tangga (KDRT) terhadap pihak perempuan.
# 10. WT (Women Trafficking) : Kasus penjualan dan perdagangan perempuan secara ilegal dengan tujuan eksploitasi.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Mengidentifikasi Kasus Kejahatan Pada Wanita Tahun 2001 - 2021

# %%
data = pd.read_csv (r'D:\KULIAH\CrimesOnWomenData.csv', sep= ",")
data.head()
# Out:
#    No              State  Year  Rape   K&A   DD   AoW   AoM    DV  WT
# 0   0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791   7
# 1   1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11   0
# 2   2              ASSAM  2001   817  1070   59   850     4  1248   0
# 3   3              BIHAR  2001   888   518  859   562    21  1558  83
# 4   4       CHHATTISGARH  2001   959   171   70  1763   161   840   0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   No      736 non-null    int64
#  1   State   736 non-null    object
#  2   Year    736 non-null    int64
#  3   Rape    736 non-null    int64
#  4   K&A     736 non-null    int64
#  5   DD      736 non-null    int64
#  6   AoW     736 non-null    int64
#  7   AoM     736 non-null    int64
#  8   DV      736 non-null    int64
#  9   WT      736 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 57.6+ KB

# %%
data['State'].value_counts() #data yang berulang - ulang 
print(data['State'].value_counts())
# Out:
# State
# ANDHRA PRADESH       21
# UTTARAKHAND          21
# PUNJAB               21
# RAJASTHAN            21
# SIKKIM               21
# TAMIL NADU           21
# TRIPURA              21
# UTTAR PRADESH        21
# WEST BENGAL          21
# ARUNACHAL PRADESH    21
# A & N ISLANDS        21
# CHANDIGARH           21
# D & N HAVELI         21
# DAMAN & DIU          21
# LAKSHADWEEP          21
# PUDUCHERRY           21
# ODISHA               21
# NAGALAND             21
# MIZORAM              21
# MEGHALAYA            21
# ASSAM                21
# BIHAR                21
# CHHATTISGARH         21
# GOA                  21
# GUJARAT              21
# HARYANA              21
# HIMACHAL PRADESH     21
# JAMMU & KASHMIR      21
# JHARKHAND            21
# KARNATAKA            21
# KERALA               21
# MADHYA PRADESH       21
# MAHARASHTRA          21
# MANIPUR              21
# TELANGANA            11
# Delhi UT             11
# Name: count, dtype: int64

# %%
data.drop_duplicates(inplace=True)

# %%
Missing_value = np.sum(data.isnull())
print(Missing_value)
# Out:
# No       0
# State    0
# Year     0
# Rape     0
# K&A      0
# DD       0
# AoW      0
# AoM      0
# DV       0
# WT       0
# dtype: int64
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
datacopy=data.copy()

# %% [markdown]
# # Data Outlier

# %%
data_cont = data.drop(['No', 'State', 'Year'], axis=1)
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14,7))
for i, ax in enumerate(axes.flat):
    if i < len(data_cont.columns):
        sns.boxplot(data_cont.iloc[:, i], ax=ax, orient='h')  
        ax.set(title=data_cont.columns.values[i])
    else:
        ax.axis('off')  
plt.tight_layout()  
plt.show()

# %% [markdown]
# # Data Kasus Kejahatan Pada Wanita 2001 - 2021

# %%
data_per_rape = data.groupby('Year')['Rape'].mean().reset_index()
print(data_per_rape)
plt.figure(figsize=(10, 6))
plt.plot(data_per_rape['Year'], data_per_year['Rape'], color='red', marker='o')
plt.title('Kasus Pemerkosaan Tahun 2001-2021')
plt.xlabel('Year')
plt.ylabel('Rape')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#     Year         Rape
# 0   2001   461.588235
# 1   2002   469.705882
# 2   2003   451.676471
# 3   2004   520.058824
# 4   2005   520.617647
# 5   2006   550.735294
# 6   2007   592.323529
# 7   2008   617.676471
# 8   2009   615.529412
# 9   2010   637.205882
# 10  2011   672.388889
# 11  2012   692.305556
# 12  2013   936.305556
# 13  2014  1020.416667
# 14  2015   962.527778
# 15  2016  1081.861111
# 16  2017   904.416667
# 17  2018   926.555556
# 18  2019   889.805556
# 19  2020   779.055556
# 20  2021   879.916667

# %%
data_per_KA = data.groupby('Year')['K&A'].mean().reset_index()
print(data_per_KA)
plt.figure(figsize=(10, 6))
plt.plot(data_per_KA['Year'], data_per_KA['K&A'], color='blue', marker='o')
plt.title('Kasus K&A Tahun 2001-2021')
plt.xlabel('Year')
plt.ylabel('KA')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#     Year          K&A
# 0   2001   402.382353
# 1   2002   400.382353
# 2   2003   367.617647
# 3   2004   432.264706
# 4   2005   430.705882
# 5   2006   480.823529
# 6   2007   566.147059
# 7   2008   641.264706
# 8   2009   708.411765
# 9   2010   825.147059
# 10  2011   987.916667
# 11  2012  1062.833333
# 12  2013  1441.138889
# 13  2014  1591.972222
# 14  2015  1646.583333
# 15  2016  1792.194444
# 16  2017  1842.583333
# 17  2018  2020.861111
# 18  2019  2021.666667
# 19  2020  1730.555556
# 20  2021  2093.583333

# %%
data_per_DD = data.groupby('Year')['DD'].mean().reset_index()
print(data_per_DD)
plt.figure(figsize=(10, 6))
plt.plot(data_per_DD['Year'], data_per_DD['DD'], color='green', marker='o')
plt.title('Kasus DD Tahun 2001-2021')
plt.xlabel('Year')
plt.ylabel('DD')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#     Year          DD
# 0   2001  198.176471
# 1   2002  196.676471
# 2   2003  178.764706
# 3   2004  202.941176
# 4   2005  196.264706
# 5   2006  220.029412
# 6   2007  233.970588
# 7   2008  236.558824
# 8   2009  242.411765
# 9   2010  242.588235
# 10  2011  239.388889
# 11  2012  228.694444
# 12  2013  224.527778
# 13  2014  279.166667
# 14  2015  212.055556
# 15  2016  211.694444
# 16  2017  207.388889
# 17  2018  199.055556
# 18  2019  197.638889
# 19  2020  193.500000
# 20  2021  187.583333

# %%
data_per_AoW = data.groupby('Year')['AoW'].mean().reset_index()
print(data_per_AoW)
plt.figure(figsize=(10, 6))
plt.plot(data_per_AoW['Year'], data_per_AoW['AoW'], color='purple', marker='o')
plt.title('Kasus AoW Tahun 2001-2021')
plt.xlabel('Year')
plt.ylabel('AoW')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#     Year          AoW
# 0   2001   988.882353
# 1   2002   985.205882
# 2   2003   954.411765
# 3   2004   999.000000
# 4   2005   982.735294
# 5   2006  1055.852941
# 6   2007  1113.705882
# 7   2008  1170.647059
# 8   2009  1122.323529
# 9   2010  1176.823529
# 10  2011     0.000000
# 11  2012  1259.555556
# 12  2013  1964.972222
# 13  2014  2284.305556
# 14  2015  2289.500000
# 15  2016  2354.055556
# 16  2017  2388.916667
# 17  2018  2474.916667
# 18  2019  2454.638889
# 19  2020  2372.000000
# 20  2021  2477.777778

# %%
data_per_AoM = data.groupby('Year')['AoM'].mean().reset_index()
print(data_per_AoM)
plt.figure(figsize=(10, 6))
plt.plot(data_per_AoM['Year'], data_per_AoM['AoM'], color='orange', marker='o')
plt.title('Kasus AoM Tahun 2001-2021')
plt.xlabel('Year')
plt.ylabel('AoM')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#     Year         AoM
# 0   2001  284.000000
# 1   2002  294.911765
# 2   2003  359.411765
# 3   2004  290.323529
# 4   2005  287.029412
# 5   2006  288.882353
# 6   2007  317.147059
# 7   2008  355.411765
# 8   2009  320.323529
# 9   2010  290.617647
# 10  2011  238.055556
# 11  2012  254.805556
# 12  2013  349.694444
# 13  2014  609.388889
# 14  2015  667.805556
# 15  2016  759.555556
# 16  2017  206.972222
# 17  2018  194.222222
# 18  2019  192.750000
# 19  2020  196.250000
# 20  2021  216.333333

# %%
data_per_DV = data.groupby('Year')['DV'].mean().reset_index()
print(data_per_DV)
plt.figure(figsize=(10, 6))
plt.plot(data_per_DV['Year'], data_per_DV['DV'], color='brown', marker='o')
plt.title('Kasus DV Tahun 2001-2021')
plt.xlabel('Year')
plt.ylabel('DV')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#     Year           DV
# 0   2001  1442.117647
# 1   2002  1444.176471
# 2   2003  1455.647059
# 3   2004  1672.558824
# 4   2005  1676.323529
# 5   2006  1805.882353
# 6   2007  2180.676471
# 7   2008  2351.676471
# 8   2009  2595.970588
# 9   2010  2724.617647
# 10  2011  2753.750000
# 11  2012  2959.083333
# 12  2013  3301.833333
# 13  2014  3413.250000
# 14  2015  3150.083333
# 15  2016  3066.055556
# 16  2017  2904.194444
# 17  2018  2868.666667
# 18  2019  3480.500000
# 19  2020  3098.583333
# 20  2021  3784.277778

# %%
data_per_WT = data.groupby('Year')['WT'].mean().reset_index()
print(data_per_WT)
plt.figure(figsize=(10, 6))
plt.plot(data_per_WT['Year'], data_per_WT['WT'], color='black', marker='o')
plt.title('Kasus WT Tahun 2001-2021')
plt.xlabel('Year')
plt.ylabel('WT')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#     Year         WT
# 0   2001   3.352941
# 1   2002   2.235294
# 2   2003   1.352941
# 3   2004   2.617647
# 4   2005   4.352941
# 5   2006   1.970588
# 6   2007   1.794118
# 7   2008   1.970588
# 8   2009   1.411765
# 9   2010   1.058824
# 10  2011  67.638889
# 11  2012  71.194444
# 12  2013  71.638889
# 13  2014  57.500000
# 14  2015  67.333333
# 15  2016  61.500000
# 16  2017  42.666667
# 17  2018  40.527778
# 18  2019  32.916667
# 19  2020  24.111111
# 20  2021  29.750000

# %% [markdown]
# # Gabungan Data Kasus Kejahatan Pada Wanita 2001 - 2021

# %%
data_rata_rata = data.pivot_table(index='Year', values=['Rape', 'K&A', 'DD', 'AoW', 'AoM', 'DV', 'WT'], aggfunc='mean')
print(data_rata_rata)
# Out:
#              AoM          AoW          DD           DV          K&A  \
# Year
# 2001  284.000000   988.882353  198.176471  1442.117647   402.382353
# 2002  294.911765   985.205882  196.676471  1444.176471   400.382353
# 2003  359.411765   954.411765  178.764706  1455.647059   367.617647
# 2004  290.323529   999.000000  202.941176  1672.558824   432.264706
# 2005  287.029412   982.735294  196.264706  1676.323529   430.705882
# 2006  288.882353  1055.852941  220.029412  1805.882353   480.823529
# 2007  317.147059  1113.705882  233.970588  2180.676471   566.147059
# 2008  355.411765  1170.647059  236.558824  2351.676471   641.264706
# 2009  320.323529  1122.323529  242.411765  2595.970588   708.411765
# 2010  290.617647  1176.823529  242.588235  2724.617647   825.147059
# 2011  238.055556     0.000000  239.388889  2753.750000   987.916667
# 2012  254.805556  1259.555556  228.694444  2959.083333  1062.833333
# 2013  349.694444  1964.972222  224.527778  3301.833333  1441.138889
# ...

# %%
plt.figure(figsize=(10,6))
data_rata_rata.plot(kind='barh', stacked=True)
plt.title('Kejahatan Per Tahun')
plt.xlabel('Rata - Rata')
plt.ylabel('Year')
plt.legend(title='Kategori')
plt.show()

# %%
plt.figure(figsize=(10,6))
data_rata_rata.plot(kind='line', stacked=False)
plt.title('Kejahatan Per Tahun')
plt.xlabel('Year')
plt.ylabel('Rata - Rata')
plt.legend(title='Kategori')
plt.show()

# %% [markdown]
# # Rata - Rata Tahun 2001 - 2021 Tentang Kasus Kejahatan Pada Wanita Disetiap Kota

# %%
data_rata_rata_2 = data.pivot_table(index='State', values=['Rape', 'K&A', 'DD', 'AoW', 'AoM', 'DV', 'WT'], aggfunc='mean')
print(data_rata_rata_2) #rata - rata di dalam rentang tahun 2001-2021
# Out:
#                            AoM          AoW           DD            DV  \
# State
# A & N ISLANDS         6.428571    26.571429     0.619048     17.380952
# ANDHRA PRADESH     2604.000000  4384.952381   388.809524   8976.714286
# ARUNACHAL PRADESH     4.619048    75.428571     0.190476     33.571429
# ASSAM               128.476190  2243.571429   131.285714   6448.333333
# BIHAR                38.095238   473.952381  1163.238095   2627.952381
# CHANDIGARH           13.380952    45.428571     3.238095     80.428571
# CHHATTISGARH        208.666667  1586.190476    85.571429    780.047619
# D & N HAVELI         40.000000   189.380952    12.190476    349.952381
# DAMAN & DIU           2.761905   173.428571     1.428571     43.428571
# Delhi UT            549.636364  2367.181818   100.545455   2465.363636
# GOA                  22.619048    70.238095     1.095238     16.952381
# GUJARAT             139.285714   862.666667    31.047619   4594.285714
# ...

# %%
for col in data_rata_rata_2.columns:
    plt.figure(figsize=(10,6))
    data_rata_rata_2[col].plot(kind='line')
    plt.title(f'Kasus {col} Terhadap Perempuan (2001-2021)')
    plt.xlabel('State')
    plt.ylabel('Frekuensi')
    plt.show()
